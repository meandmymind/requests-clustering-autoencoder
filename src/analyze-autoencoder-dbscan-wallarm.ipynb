# %%
import pandas as pd
import numpy as np
import requests
import os

from keras.engine.topology import Layer, InputSpec
from keras.layers import Dense, Input, Embedding
from keras.layers.recurrent import LSTM
from keras.models import Model
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.sequence import pad_sequences
import keras.backend as K

from utils.vocab import Vocabulary
from sklearn.cluster import KMeans
from joblib import load

from utils.plot_utils import plot_and_save_history
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Utils

# %%
class AutoEncoder(object):
    """ 4-layer LSTM Autoencoder
    Parameters
        vocab: Vocabulary object that stores char-to-int mappings 
            and text processing functions.
        hidden_size: Dimension of latent space between encoder and decoder.
            Default: 64.
        dropout: Fraction of units to be randomly ignored during training.
            Both linear and recurrent dropout are used.
            Default: 0.2.
    """
    DEFAULT_HIDDEN_UNITS = 64
    DEFAULT_DROPOUT = 0.2
    DEFAULT_BATCH_SIZE = 64
    DEFAULT_EPOCHS = 100
    DEFAULT_MODEL_WEIGHT_PATH = './models/autoencoder-weights.h5'
    model_name = 'autoencoder'

    def __init__(self, vocab, hidden_size=None, dropout=None):
        if not hidden_size:
            self.hidden_size = AutoEncoder.DEFAULT_HIDDEN_UNITS
        if not dropout:
            self.dropout = AutoEncoder.DEFAULT_DROPOUT
            
        self.vocab = vocab
        self.vocab_size = vocab.vocab_size
        self.max_input_seq_length = vocab.max_input_seq_length

        encoder_inputs = Input(shape=(None,), name='encoder_inputs')
        encoder_embedding = Embedding(input_dim=self.vocab_size,
                                      output_dim=self.hidden_size,
                                      input_length=self.max_input_seq_length,
                                      name='encoder_embedding')
        encoder_lstm = LSTM(units=self.hidden_size,
                            return_state=True,
                            dropout=self.dropout,
                            recurrent_dropout=self.dropout,
                            name='encoder_lstm')
        encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_embedding(encoder_inputs))
        encoder_states = [encoder_state_h, encoder_state_c]

        decoder_inputs = Input(shape=(None, self.vocab_size), name='decoder_inputs')
        decoder_lstm = LSTM(units=self.hidden_size, return_state=True,
                            return_sequences=True, name='decoder_lstm')
        decoder_outputs, decoder_state_h, decoder_state_c = decoder_lstm(decoder_inputs,
                                                                         initial_state=encoder_states)
        decoder_dense = Dense(units=self.vocab_size, activation='softmax', name='decoder_dense')
        decoder_outputs = decoder_dense(decoder_outputs)

        model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

        model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

        self.model = model

        self.encoder_model = Model(encoder_inputs, encoder_states)

        decoder_state_inputs = [Input(shape=(self.hidden_size,)), Input(shape=(self.hidden_size,))]
        decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs,
                                                         initial_state=decoder_state_inputs)
        decoder_states = [state_h, state_c]
        decoder_outputs = decoder_dense(decoder_outputs)
        self.decoder_model = Model([decoder_inputs] + decoder_state_inputs,
                                   [decoder_outputs] + decoder_states)

    def load_weights(self, weight_file_path):
        if os.path.exists(weight_file_path):
            self.model.load_weights(weight_file_path)

    def generate_batch(self, samples, batch_size):
        num_batches = len(samples) // batch_size
        while True:
            for batchIdx in range(0, num_batches):
                start = batchIdx * batch_size
                end = (batchIdx + 1) * batch_size
                encoder_input_data_batch = pad_sequences(samples[start:end], self.max_input_seq_length)
                decoder_target_data_batch = np.zeros(shape=(batch_size, self.max_input_seq_length,
                                                            self.vocab_size))
                decoder_input_data_batch = np.zeros(shape=(batch_size, self.max_input_seq_length,
                                                           self.vocab_size))
                for textIdx, chars in enumerate(samples[start:end]):
                    for idx, char in enumerate(chars):
                        if char != 1: # not <UNK>
                            decoder_input_data_batch[textIdx, idx, char] = 1
                            if idx > 0:
                                decoder_target_data_batch[textIdx, idx - 1, char] = 1
                yield [encoder_input_data_batch, decoder_input_data_batch], decoder_target_data_batch

    def fit(self, Xtrain, Xtest, epochs=None, batch_size=None, weight_file_path=None):
        """
        Train model.
        Parameters:
            Xtrain: Array of strings for training.
            Xtest: Array of strings for validation.
            epochs: Number of full forward passes of all training samples.
                Default: 50.
            batch_size: Number of samples to pass for one iteration.
                Default: 64.
            weight_file_path: File path with extension '.h5'
                for saving weights of the network. (https://www.h5py.org/)
                Default: ./models/autoencoder-weights.h5
        """

        if not epochs:
            epochs = AutoEncoder.DEFAULT_EPOCHS
        if not batch_size:
            batch_size = AutoEncoder.DEFAULT_BATCH_SIZE
        if not weight_file_path:
            weight_file_path = AutoEncoder.DEFAULT_WEIGHT_FILE_PATH

        checkpoint = ModelCheckpoint(weight_file_path)

        Xtrain = self.vocab.transform_texts(Xtrain)
        Xtest = self.vocab.transform_texts(Xtest)

        train_gen = self.generate_batch(Xtrain, batch_size)
        test_gen = self.generate_batch(Xtest, batch_size)

        train_num_batches = len(Xtrain) // batch_size
        test_num_batches = len(Xtest) // batch_size

        history = self.model.fit_generator(generator=train_gen, steps_per_epoch=train_num_batches,
                                           epochs=epochs, verbose=True,
                                           validation_data=test_gen, validation_steps=test_num_batches,
                                           callbacks=[checkpoint])
        self.model.save_weights(weight_file_path)
        return history

    def predict(self, input_text):
        """
        Process input texts and reconstruct them.
        Used to check how well model "understands" input texts.
        Parameters:
             input_text: 
        """
        input_seq = self.vocab.transform_texts([input_text])
        states_value = self.encoder_model.predict(input_seq)
        target_seq = np.zeros((1, 1, self.vocab_size))
        target_seq[0, 0, self.vocab.char2idx['<START>']] = 1
        target_text = ''
        target_text_len = 0
        terminated = False
        while not terminated:
            output_tokens, h, c = self.decoder_model.predict([target_seq] + states_value)

            sample_token_idx = np.argmax(output_tokens[0, -1, :])
            sample_char = self.vocab.idx2char[sample_token_idx]
            target_text_len += 1

            if sample_char != '<START>' and sample_char != '<END>':
                target_text += ' ' + sample_char

            if sample_char == '<END>' or target_text_len >= self.max_input_seq_length:
                terminated = True

            target_seq = np.zeros((1, 1, self.vocab_size))
            target_seq[0, 0, sample_token_idx] = 1

            states_value = [h, c]
        return target_text.strip()

# %%
def get_features(vectors):
    # vector: string -> vector_embedding: [char_indices]
    # [char_indices] are padded with 0 to the right
    vector_embedding = vocab.transform_texts([vector])
    
    # vector_embedding: [char_indices] -> encoders_states: [state_h, state_c]
    encoder_states = encoder.predict([vector_embedding])
    
    # use state_h as feature
    vector_features = encoder_states[0]
    
    return vector_features

# %%
def predict_class(vector_features):
    vector_class = kmeans.predict(vector_features)[0]
    # "0"-class is invalid
    if vector_class == 0:
        vector_class = 25
    return vector_class

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Load data

# %%
pd.set_option('display.max_colwidth', 100)

# %%
data = pd.read_csv('../data/old-wallarm.csv', encoding='utf-8', lineterminator='\n')
data = data.fillna('<BLANK>')

# %% [markdown]
# ### Load autoencoder

# %%
from keras import backend as K

K.set_learning_phase(0) #set testing phase

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = ''

# %%
vocab = Vocabulary()
vocab.vocab_file = './vocab-wallarm.json'
vocab.make_vocab(data['text'])
autoencoder = AutoEncoder(vocab)
autoencoder.load_weights('./models/train-wallarm.h5')
encoder = autoencoder.encoder_model
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1238: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1204: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# ### Train K-Means

# %%
vector_embeddings = vocab.transform_texts(data['text'])
encoder_states = encoder.predict(vector_embeddings)
vector_features = encoder_states[0]

# %% [markdown]
# ### Predict for eps=0.5

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(n_jobs=-1)
labels = dbscan.fit_predict(vector_features)
result = pd.DataFrame(data)
result['class'] = labels

# %%
results = result['class'].value_counts()

# %%
results
# Out:
#  0      27703
#  2      26820
# -1       8519
#  41       152
#  23       120
#  7        102
#  36        79
#  30        79
#  1         71
#  4         66
#  28        64
#  14        57
#  16        53
#  47        43
#  83        42
#  51        35
#  12        34
#  20        34
#  59        34
#  26        34
#  39        33
#  101       33
#  24        33
#  111       32
#  5         31
#  96        29
#  66        28
#  68        26
#  11        26
#  18        25
#         ...
#  86         5
#  87         5
#  145        5
#  151        5
#  144        5
#  152        5
#  154        5
#  155        5
#  94         5
#  158        5
#  34         5
#  35         5
#  169        5
#  168        5
#  162        5
#  139        5
#  99         5
#  75         5
#  140        5
#  192        4
#  189        4
#  174        4
#  185        4
#  153        4
#  195        4
#  186        3
#  124        3
#  181        3
#  72         3
#  170        2
# Name: class, Length: 200, dtype: int64

# %%
result[result['class'] == 2]
# Out:
#            id  \
# 3       28821
# 5       74446
# 8       76096
# 11      33516
# 14      44176
# 17      76039
# 20      53171
# 22      94425
# 27      81271
# 28      60015
# 29      53814
# 32      56144
# 33      57671
# 35       8868
# 37      93692
# 41      74994
# 42      93205
# 43      53629
# 44      94626
# 47      45689
# 49      98144
# 53      57845
# 54      96686
# 55      80978
# 56       1909
# 57      51863
# 58       6247
# 60      74544
# 61       9509
# 62      25291
# ...       ...
# 65793   53647
# 65794   78869
# 65795   34816
# 65796   52888
# 65797   82246
# 65801   22730
# 65802  100647
# 65808   48654
# 65810   42456
# 65812   19703
# 65815   50955
# 65818   61426
# 65819  101294
# 65821     284
# 65823   11535
# 65824   60237
# 65827   93122
# 65828    2791
# 65829   54636
# 65834   62624
# 65835   96676
# 65837   50749
# 65839   50555
# 65840   67100
# 65841   75956
# 65843    5928
# 65845   51457
# 65846   96598
# 65848   67199
# 65853    1762
#
#                                                                           text  \
# 3                                                               D8j+oNbylTIGw=
# 5                                                            " union/*M!719 */
# 8                                                               "  /*M!union*/
# 11                                       kEC+oNOwUkgJOk4bn7Jm9wOWOT6V ... f9g=
# 14       https://example.example.ru/krasota/massage/?seamless=7&tabName=ORDER#
# 17                                                               ' union/*M!*/
# 20                                                                %F3%3F%74%BF
# 22                                       %5Ca%65HrEf=VbScRiPt:MsgBox(14527)%7E
# 27                                                            view' aNd '8'='6
# 28      755 union/*mgjrer qqypxc */distinct\tselectdpohuefrom\texample.example
# 29                                                          Sequoia F.3L Falco
# 32                                                      941 or/**/tvguaf()=768
# 33          664 and 'esprrx'>exelbw#gahbcp 71 mvnfng lxdmep bovfon rwabxc \r()
# 35                                                             rip curl"\t\ns
# 37                                       %4Ca%19HrEf=VbScRiPt:MsgBox(75523)%2E
# 41                                                              '  union/*M!*/
# 42                                %52%9E%8Clink%58rel=prefetch%66href=79594%1E
# 43                                                            Torrington, Wyo.
# 44                                 %78%4E%2Ca%88HrEf=VbScRiPt:MsgBox(85837)%5E
# 47                                            fe6-11de86c1324d-or-59f495d1-7a3
# 49                          v;s=%76%7E%1Clink%76rel=prefetch%21href=32157%6E;s
# 53                                                     916 andhnagmy( 849)>=21
# 54                                %73%1E%1Clink%55rel=prefetch%69href=61666%8E
# 55                                         !S!WCRTESTINPUT264342!E!' aNd '%'='
# 56                                                                  )G](by!bvK
# 57                                                                 Per Hansson
# 58                                                              æB©""Or1.A¶Ä
# 60                                                              51  union/*!*/
# 61                                                                  DeLeTe#752
# 62                                         +|Ph|Eq|lingot or 2 g argor heraeus
# ...                                                                        ...
# 65793                                                            House (genre)
# 65794                                                       JSP+6.8' or 'b'='a
# 65795                                           Mpi/oNDrASOUvzYGBXd6qp9Q=; km_
# 65796                                                 Michael P%C3%A4rez Ortiz
# 65797                                                        476_4' aNd '8'='8
# 65801                   /search?string=Expression 34737XL&rootCategory=&sort=9
# 65802               51568%7C/textarea%4E%2Clink%34rel=prefetch%84href=11165%3E
# 65808                                       @racheljoness_ Come to the library
# 65810                                   яс.   48967(«.7471₽&71@@&₽(;&)йвсия￼4@
# 65812                                                         YXl/ONnFrYGAEVE=
# 65815                                                             %F7%4F%7D%5A
# 65818                                714 union\tselect/**/"faiwex"\tfromiyipmm
# 65819                             %71%1E%8Clink%63rel=prefetch%47href=25638%9E
# 65821                               1#ÁSrc7TØñCØÛH¿¶èq ... Î9&#6È´-e
# 65823                                           MSM&FORM=MBD ... ion=click&nam
# 65824  276 unionselect\t(wcsgyl/*882 bedfcf */((778)))\tfrom#\rexample.example
# 65827            left'%79()&%94%4Cacx%4E%6CScRiPt%27%9EvQez(4282)%8C/ScRiPt%3E
# 65828                           /suggest?q=snmp telnet&cat=2&locationId=835347
# 65829                          58  union /*!*/select(eindxb\t()), (woilds(88))
# 65834              " or/*!932 93<( select\t*/rqxhua(13)\tfrom example.example)
# 65835          wiki:example.example%18%9E%8Ca%82HrEf=VbScRiPt:MsgBox(91182)%1E
# 65837                                                        Cambarus montanus
# 65839                                                          Bryni of Sussex
# 65840                                                         478  /*M!union*/
# 65841                                                          241  union/*!*/
# 65843                                    fde/OnuGqHfjaA4mHsp2jSxUCfOP ... XwY=
# 65845                                                       Methanocorpusculum
# 65846                                    %5Ca%64HrEf=VbScRiPt:MsgBox(84858)%9E
# 65848                                                          65  union/*M!*/
# 65853                                                           na/<object wid
#
#        injection  class
# 3          False      2
# 5           True      2
# 8           True      2
# 11         False      2
# 14         False      2
# 17          True      2
# 20         False      2
# 22          True      2
# 27          True      2
# 28          True      2
# 29         False      2
# 32          True      2
# 33          True      2
# 35         False      2
# 37          True      2
# 41          True      2
# 42          True      2
# 43         False      2
# 44          True      2
# 47         False      2
# 49          True      2
# 53          True      2
# 54          True      2
# 55          True      2
# 56         False      2
# 57         False      2
# 58         False      2
# 60          True      2
# 61         False      2
# 62         False      2
# ...          ...    ...
# 65793      False      2
# 65794       True      2
# 65795      False      2
# 65796      False      2
# 65797       True      2
# 65801      False      2
# 65802       True      2
# 65808      False      2
# 65810      False      2
# 65812      False      2
# 65815      False      2
# 65818       True      2
# 65819       True      2
# 65821      False      2
# 65823      False      2
# 65824       True      2
# 65827       True      2
# 65828      False      2
# 65829       True      2
# 65834       True      2
# 65835       True      2
# 65837      False      2
# 65839      False      2
# 65840       True      2
# 65841       True      2
# 65843      False      2
# 65845      False      2
# 65846       True      2
# 65848       True      2
# 65853      False      2
#
# [26820 rows x 4 columns]

# %%
result[(result['class'] == 2) & (result['injection'] == True)]
# Out:
#            id  \
# 5       74446
# 8       76096
# 17      76039
# 22      94425
# 27      81271
# 28      60015
# 32      56144
# 33      57671
# 37      93692
# 41      74994
# 42      93205
# 44      94626
# 49      98144
# 53      57845
# 54      96686
# 55      80978
# 60      74544
# 66      81866
# 69      54666
# 73      88020
# 79      66800
# 87      77889
# 96      75795
# 100    104961
# 102     66269
# 105     56722
# 106     59001
# 111     66424
# 114     65936
# 126     67472
# ...       ...
# 65729   74666
# 65730   80584
# 65731   88290
# 65732   56993
# 65733   56807
# 65734  100511
# 65738   92489
# 65745   66408
# 65755   66927
# 65756   80911
# 65758   82307
# 65761   67140
# 65768   73262
# 65772   90680
# 65774   74071
# 65783   72936
# 65794   78869
# 65797   82246
# 65802  100647
# 65818   61426
# 65819  101294
# 65824   60237
# 65827   93122
# 65829   54636
# 65834   62624
# 65835   96676
# 65840   67100
# 65841   75956
# 65846   96598
# 65848   67199
#
#                                                                           text  \
# 5                                                            " union/*M!719 */
# 8                                                               "  /*M!union*/
# 17                                                               ' union/*M!*/
# 22                                       %5Ca%65HrEf=VbScRiPt:MsgBox(14527)%7E
# 27                                                            view' aNd '8'='6
# 28      755 union/*mgjrer qqypxc */distinct\tselectdpohuefrom\texample.example
# 32                                                      941 or/**/tvguaf()=768
# 33          664 and 'esprrx'>exelbw#gahbcp 71 mvnfng lxdmep bovfon rwabxc \r()
# 37                                       %4Ca%19HrEf=VbScRiPt:MsgBox(75523)%2E
# 41                                                              '  union/*M!*/
# 42                                %52%9E%8Clink%58rel=prefetch%66href=79594%1E
# 44                                 %78%4E%2Ca%88HrEf=VbScRiPt:MsgBox(85837)%5E
# 49                          v;s=%76%7E%1Clink%76rel=prefetch%21href=32157%6E;s
# 53                                                     916 andhnagmy( 849)>=21
# 54                                %73%1E%1Clink%55rel=prefetch%69href=61666%8E
# 55                                         !S!WCRTESTINPUT264342!E!' aNd '%'='
# 60                                                              51  union/*!*/
# 66                                                                1' aNd '%'='
# 69                                           "  union\t/*!28 select */crmgqu()
# 73                               /%6Cscript%6Exss%3C/script%example.example%43
# 79                                                              48  union/*!*/
# 87                                           for_business AND 4456=8457-- LyQc
# 96                                                              '  union/*M!*/
# 100                               %55%5E%9Clink%38rel=prefetch%54href=23453%4E
# 102                                                       261  union/*M!559 */
# 105                     755 or\t561=kviktj( (efkyns()), ( "lnthxf"), 'pstsgp')
# 106                                      97 and(select gapsmr fromkxpopf)<>536
# 111                                                           975  union/*M!*/
# 114                                                          "  union/*!593 */
# 126                                                            945  union/*!*/
# ...                                                                        ...
# 65729                                                           58  union/*!*/
# 65730                                                          all' aNd '9'='9
# 65731                                    %8Ca%91HrEf=VbScRiPt:MsgBox(22947)%9E
# 65732                                    332 or\twovfgh(\t('ofexft'))>"ittiqk"
# 65733                                               421 or#\r'qjiigm'=trrqgc()
# 65734                                    %3Ca%76HrEf=VbScRiPt:MsgBox(84378)%3E
# 65738                             %62%4E%4Clink%54rel=prefetch%16href=46419%2E
# 65745                                                       18  union/*!323 */
# 65755                                                          141  union/*!*/
# 65756                                      !S!WCRTESTINPUT924254!E!' aNd '%'='
# 65758                                                        556_9' aNd '9'='7
# 65761                                                     xkelqo'  union/*M!*/
# 65768                                   455  or/*M!97 19>=pbgjeh(*/(ticcvm()))
# 65772                '%52()&%67%7Cacx%6E%3CScRiPt%89%4E4u3X(7669)%2C/ScRiPt%5E
# 65774                                      '  and /*!jndqch((pqxkvp ()))*/<927
# 65783                                           61  or\t369=ocrkms ()/*!253 */
# 65794                                                       JSP+6.8' or 'b'='a
# 65797                                                        476_4' aNd '8'='8
# 65802               51568%7C/textarea%4E%2Clink%34rel=prefetch%84href=11165%3E
# 65818                                714 union\tselect/**/"faiwex"\tfromiyipmm
# 65819                             %71%1E%8Clink%63rel=prefetch%47href=25638%9E
# 65824  276 unionselect\t(wcsgyl/*882 bedfcf */((778)))\tfrom#\rexample.example
# 65827            left'%79()&%94%4Cacx%4E%6CScRiPt%27%9EvQez(4282)%8C/ScRiPt%3E
# 65829                          58  union /*!*/select(eindxb\t()), (woilds(88))
# 65834              " or/*!932 93<( select\t*/rqxhua(13)\tfrom example.example)
# 65835          wiki:example.example%18%9E%8Ca%82HrEf=VbScRiPt:MsgBox(91182)%1E
# 65840                                                         478  /*M!union*/
# 65841                                                          241  union/*!*/
# 65846                                    %5Ca%64HrEf=VbScRiPt:MsgBox(84858)%9E
# 65848                                                          65  union/*M!*/
#
#        injection  class
# 5           True      2
# 8           True      2
# 17          True      2
# 22          True      2
# 27          True      2
# 28          True      2
# 32          True      2
# 33          True      2
# 37          True      2
# 41          True      2
# 42          True      2
# 44          True      2
# 49          True      2
# 53          True      2
# 54          True      2
# 55          True      2
# 60          True      2
# 66          True      2
# 69          True      2
# 73          True      2
# 79          True      2
# 87          True      2
# 96          True      2
# 100         True      2
# 102         True      2
# 105         True      2
# 106         True      2
# 111         True      2
# 114         True      2
# 126         True      2
# ...          ...    ...
# 65729       True      2
# 65730       True      2
# 65731       True      2
# 65732       True      2
# 65733       True      2
# 65734       True      2
# 65738       True      2
# 65745       True      2
# 65755       True      2
# 65756       True      2
# 65758       True      2
# 65761       True      2
# 65768       True      2
# 65772       True      2
# 65774       True      2
# 65783       True      2
# 65794       True      2
# 65797       True      2
# 65802       True      2
# 65818       True      2
# 65819       True      2
# 65824       True      2
# 65827       True      2
# 65829       True      2
# 65834       True      2
# 65835       True      2
# 65840       True      2
# 65841       True      2
# 65846       True      2
# 65848       True      2
#
# [13882 rows x 4 columns]

# %%
homogeneity
# Out:
# {0: 0.574,
#  1: 0.507,
#  2: 1.0,
#  3: 0.518,
#  4: 1.0,
#  5: 1.0,
#  6: 1.0,
#  7: 0.5,
#  8: 1.0,
#  9: 0.857,
#  10: 1.0,
#  11: 1.0,
#  12: 1.0,
#  13: 0.971,
#  14: 1.0,
#  15: 1.0,
#  16: 1.0,
#  17: 0.887,
#  18: 1.0,
#  19: 1.0,
#  20: 1.0,
#  21: 1.0,
#  22: 1.0,
#  23: 1.0,
#  24: 1.0,
#  25: 1.0,
#  26: 1.0,
#  27: 1.0,
#  28: 1.0,
#  29: 0.688,
#  30: 1.0,
#  31: 0.987,
#  32: 1.0,
#  33: 1.0,
#  34: 1.0,
#  35: 1.0,
#  36: 1.0,
#  37: 0.785,
#  38: 1.0,
#  39: 1.0,
#  40: 1.0,
#  41: 1.0,
#  42: 1.0,
#  43: 1.0,
#  44: 1.0,
#  45: 1.0,
#  46: 1.0,
#  47: 1.0,
#  48: 1.0,
#  49: 1.0,
#  50: 1.0,
#  51: 1.0,
#  52: 0.971,
#  53: 1.0,
#  54: 1.0,
#  55: 1.0,
#  56: 1.0,
#  57: 1.0,
#  58: 1.0,
#  59: 1.0,
#  60: 1.0,
#  61: 1.0,
#  62: 1.0,
#  63: 0.833,
#  64: 1.0,
#  65: 1.0,
#  66: 1.0,
#  67: 0.964,
#  68: 1.0,
#  69: 0.962,
#  70: 1.0,
#  71: 1.0,
#  72: 1.0,
#  73: 1.0,
#  74: 1.0,
#  75: 1.0,
#  76: 1.0,
#  77: 1.0,
#  78: 0.909,
#  79: 1.0,
#  80: 1.0,
#  81: 1.0,
#  82: 1.0,
#  83: 1.0,
#  84: 1.0,
#  85: 1.0,
#  86: 1.0,
#  87: 1.0,
#  88: 1.0,
#  89: 1.0,
#  90: 1.0,
#  91: 1.0,
#  92: 1.0,
#  93: 1.0,
#  94: 1.0,
#  95: 1.0,
#  96: 1.0,
#  97: 1.0,
#  98: 1.0,
#  99: 1.0,
#  100: 1.0,
#  101: 1.0,
#  102: 1.0,
#  103: 1.0,
#  104: 1.0,
#  105: 1.0,
#  106: 1.0,
#  107: 1.0,
#  108: 1.0,
#  109: 1.0,
#  110: 1.0,
#  111: 0.833,
#  112: 1.0,
#  113: 1.0,
#  114: 1.0,
#  115: 1.0,
#  116: 1.0,
#  117: 1.0,
#  118: 1.0,
#  119: 1.0,
#  120: 1.0,
#  121: 1.0,
#  122: 1.0,
#  123: 1.0,
#  124: 1.0,
#  125: 1.0,
#  126: 1.0,
#  127: 1.0,
#  128: 1.0,
#  129: 1.0,
#  130: 1.0,
#  131: 1.0,
#  132: 1.0,
#  133: 1.0,
#  134: 1.0,
#  135: 1.0,
#  136: 1.0,
#  137: 1.0,
#  138: 1.0,
#  139: 1.0,
#  140: 1.0,
#  141: 1.0,
#  142: 1.0,
#  143: 1.0,
#  144: 1.0,
#  145: 1.0,
#  146: 1.0,
#  147: 1.0,
#  148: 1.0,
#  149: 1.0,
#  150: 1.0,
#  151: 1.0,
#  152: 1.0,
#  153: 1.0,
#  154: 1.0,
#  155: 1.0,
#  156: 1.0,
#  157: 1.0,
#  158: 1.0,
#  159: 1.0,
#  160: 1.0,
#  161: 0.8,
#  162: 1.0,
#  163: 1.0,
#  164: 1.0,
#  165: 1.0,
#  166: 1.0,
#  167: 1.0,
#  168: 1.0,
#  169: 1.0,
#  170: 1.0,
#  171: 1.0,
#  172: 1.0,
#  173: 0.95,
#  174: 1.0,
#  175: 1.0,
#  176: 1.0,
#  177: 1.0,
#  178: 1.0,
#  179: 1.0,
#  180: 0.889,
#  181: 1.0,
#  182: 1.0,
#  183: 1.0,
#  184: 1.0,
#  185: 1.0,
#  186: 1.0,
#  187: 0.667,
#  188: 1.0,
#  189: 1.0,
#  190: 1.0,
#  191: 1.0,
#  192: 1.0,
#  193: 1.0,
#  194: 1.0,
#  195: 1.0,
#  196: 1.0,
#  197: 0.8,
#  198: 1.0,
#  199: 1.0}

# %%
homogeneity[2]
# Out:
# 0.54

# %%
result[result['class'] == 2]
# Out:
#            id  \
# 3       28821
# 5       74446
# 8       76096
# 11      33516
# 14      44176
# 17      76039
# 20      53171
# 22      94425
# 27      81271
# 28      60015
# 29      53814
# 32      56144
# 33      57671
# 35       8868
# 37      93692
# 41      74994
# 42      93205
# 43      53629
# 44      94626
# 47      45689
# 49      98144
# 53      57845
# 54      96686
# 55      80978
# 56       1909
# 57      51863
# 58       6247
# 60      74544
# 61       9509
# 62      25291
# ...       ...
# 65793   53647
# 65794   78869
# 65795   34816
# 65796   52888
# 65797   82246
# 65801   22730
# 65802  100647
# 65808   48654
# 65810   42456
# 65812   19703
# 65815   50955
# 65818   61426
# 65819  101294
# 65821     284
# 65823   11535
# 65824   60237
# 65827   93122
# 65828    2791
# 65829   54636
# 65834   62624
# 65835   96676
# 65837   50749
# 65839   50555
# 65840   67100
# 65841   75956
# 65843    5928
# 65845   51457
# 65846   96598
# 65848   67199
# 65853    1762
#
#                                                                           text  \
# 3                                                               D8j+oNbylTIGw=
# 5                                                            " union/*M!719 */
# 8                                                               "  /*M!union*/
# 11                                       kEC+oNOwUkgJOk4bn7Jm9wOWOT6V ... f9g=
# 14       https://example.example.ru/krasota/massage/?seamless=7&tabName=ORDER#
# 17                                                               ' union/*M!*/
# 20                                                                %F3%3F%74%BF
# 22                                       %5Ca%65HrEf=VbScRiPt:MsgBox(14527)%7E
# 27                                                            view' aNd '8'='6
# 28      755 union/*mgjrer qqypxc */distinct\tselectdpohuefrom\texample.example
# 29                                                          Sequoia F.3L Falco
# 32                                                      941 or/**/tvguaf()=768
# 33          664 and 'esprrx'>exelbw#gahbcp 71 mvnfng lxdmep bovfon rwabxc \r()
# 35                                                             rip curl"\t\ns
# 37                                       %4Ca%19HrEf=VbScRiPt:MsgBox(75523)%2E
# 41                                                              '  union/*M!*/
# 42                                %52%9E%8Clink%58rel=prefetch%66href=79594%1E
# 43                                                            Torrington, Wyo.
# 44                                 %78%4E%2Ca%88HrEf=VbScRiPt:MsgBox(85837)%5E
# 47                                            fe6-11de86c1324d-or-59f495d1-7a3
# 49                          v;s=%76%7E%1Clink%76rel=prefetch%21href=32157%6E;s
# 53                                                     916 andhnagmy( 849)>=21
# 54                                %73%1E%1Clink%55rel=prefetch%69href=61666%8E
# 55                                         !S!WCRTESTINPUT264342!E!' aNd '%'='
# 56                                                                  )G](by!bvK
# 57                                                                 Per Hansson
# 58                                                              æB©""Or1.A¶Ä
# 60                                                              51  union/*!*/
# 61                                                                  DeLeTe#752
# 62                                         +|Ph|Eq|lingot or 2 g argor heraeus
# ...                                                                        ...
# 65793                                                            House (genre)
# 65794                                                       JSP+6.8' or 'b'='a
# 65795                                           Mpi/oNDrASOUvzYGBXd6qp9Q=; km_
# 65796                                                 Michael P%C3%A4rez Ortiz
# 65797                                                        476_4' aNd '8'='8
# 65801                   /search?string=Expression 34737XL&rootCategory=&sort=9
# 65802               51568%7C/textarea%4E%2Clink%34rel=prefetch%84href=11165%3E
# 65808                                       @racheljoness_ Come to the library
# 65810                                   яс.   48967(«.7471₽&71@@&₽(;&)йвсия￼4@
# 65812                                                         YXl/ONnFrYGAEVE=
# 65815                                                             %F7%4F%7D%5A
# 65818                                714 union\tselect/**/"faiwex"\tfromiyipmm
# 65819                             %71%1E%8Clink%63rel=prefetch%47href=25638%9E
# 65821                               1#ÁSrc7TØñCØÛH¿¶èq ... Î9&#6È´-e
# 65823                                           MSM&FORM=MBD ... ion=click&nam
# 65824  276 unionselect\t(wcsgyl/*882 bedfcf */((778)))\tfrom#\rexample.example
# 65827            left'%79()&%94%4Cacx%4E%6CScRiPt%27%9EvQez(4282)%8C/ScRiPt%3E
# 65828                           /suggest?q=snmp telnet&cat=2&locationId=835347
# 65829                          58  union /*!*/select(eindxb\t()), (woilds(88))
# 65834              " or/*!932 93<( select\t*/rqxhua(13)\tfrom example.example)
# 65835          wiki:example.example%18%9E%8Ca%82HrEf=VbScRiPt:MsgBox(91182)%1E
# 65837                                                        Cambarus montanus
# 65839                                                          Bryni of Sussex
# 65840                                                         478  /*M!union*/
# 65841                                                          241  union/*!*/
# 65843                                    fde/OnuGqHfjaA4mHsp2jSxUCfOP ... XwY=
# 65845                                                       Methanocorpusculum
# 65846                                    %5Ca%64HrEf=VbScRiPt:MsgBox(84858)%9E
# 65848                                                          65  union/*M!*/
# 65853                                                           na/<object wid
#
#        injection  class
# 3          False      2
# 5           True      2
# 8           True      2
# 11         False      2
# 14         False      2
# 17          True      2
# 20         False      2
# 22          True      2
# 27          True      2
# 28          True      2
# 29         False      2
# 32          True      2
# 33          True      2
# 35         False      2
# 37          True      2
# 41          True      2
# 42          True      2
# 43         False      2
# 44          True      2
# 47         False      2
# 49          True      2
# 53          True      2
# 54          True      2
# 55          True      2
# 56         False      2
# 57         False      2
# 58         False      2
# 60          True      2
# 61         False      2
# 62         False      2
# ...          ...    ...
# 65793      False      2
# 65794       True      2
# 65795      False      2
# 65796      False      2
# 65797       True      2
# 65801      False      2
# 65802       True      2
# 65808      False      2
# 65810      False      2
# 65812      False      2
# 65815      False      2
# 65818       True      2
# 65819       True      2
# 65821      False      2
# 65823      False      2
# 65824       True      2
# 65827       True      2
# 65828      False      2
# 65829       True      2
# 65834       True      2
# 65835       True      2
# 65837      False      2
# 65839      False      2
# 65840       True      2
# 65841       True      2
# 65843      False      2
# 65845      False      2
# 65846       True      2
# 65848       True      2
# 65853      False      2
#
# [26820 rows x 4 columns]

# %%
clusters['counts'] = pd.concat()

# %%
n_clusters = result['class'].unique().size

# %%
result[result['class'] == 0]
# Out:
#            id  \
# 0       59290
# 1       54992
# 2       64287
# 6       71873
# 7       87153
# 9       42354
# 12     101157
# 13      74110
# 15      16094
# 16      83110
# 21     100344
# 23      88449
# 24      78054
# 25      97498
# 30      13209
# 34      85649
# 36      92795
# 39      83866
# 45      69454
# 46       7454
# 50      90437
# 51      31227
# 52      97516
# 59      29481
# 63      85111
# 64      35367
# 67      41189
# 68       6038
# 71      86129
# 74      10575
# ...       ...
# 65781   85586
# 65785   90327
# 65787   11804
# 65789   33381
# 65791   69008
# 65792   42736
# 65798   87521
# 65799  105162
# 65803   54827
# 65804   10215
# 65806   20126
# 65807   70006
# 65809   20792
# 65811   44847
# 65813   44224
# 65814   69839
# 65816   91897
# 65817   93410
# 65826   28332
# 65830   55601
# 65831   19108
# 65832   21528
# 65833   11731
# 65836   32300
# 65838  103381
# 65842   39011
# 65847   94569
# 65849  101752
# 65850    1268
# 65852   26176
#
#                                                                                                       text  \
# 0                           ' and/**/38>( select\t(622)/**/from/*362 emhgpv gpnqdn odpxkn qgnoyb */htipaw)
# 1      shqpkt" union /*!426 all\t*/(select kwicwt(\t(\tyaaoda\t()), (236), (konjlq()),  619, nyknas ())...
# 2      nhnqag" uniondistinct--154 298 plhlre exaloq unyote \r(select (rpfeir#15 256 15 rttlat 66 gsjxjq...
# 6      194 union#93 yguxsk 669 393 \r\tselect\t\texlgjh(), cirwsi((\t616), (#\r'qbtidf'), (#\r'xhqujm')...
# 7                        /example.example?%7Cmeta%82http-equiv=Set-Cookie%59content=%11testizfx=5232%28%6E
# 9             /handler_sync_example.example?i=j4sR/mhZpekzcpKcC5cUoFHo5e42TQeA6YzVZuR3mhhuaivOgsA/oncCkpo=
# 12             %24%3E%7Cscript%3Ealert(%12sap_its_urlmime_example.example%45)%4C/script%5E%1Cimg%78src=%33
# 13                              794  and bjwdqp((318), \t/*M!354 932, (625),*/ (275), (91), 365, (22))=672
# 15            /handler_sync_example.example?i=Ypg//ONuVSKGXMnxmNJk8d6NQDTWwBs9OUBxw7FuiARcp4PPJBes4cIR26Q=
# 16     ru1527924556435" UNION SELECT CHAR(78,655,28,88,91,84),CHAR(68,568,67,78,68,22),CHAR(35,976,31,5...
# 21     %1C!--%16BEGIN%79JIVOSITE%58CODE%34%1Bliteral%2D%93--%7E%94%4Cscript%98type='text/javascript'%3E...
# 23                        '%23@--%4E%4C/style%4E%3C/scRipt%6E%5CscRipt%4Enetsparker(1x337A7D)%9C/scRipt%7E
# 24     235548452427489' UNION SELECT CHAR(53,272,24,39,56,39),CHAR(65,164,53,65,68,54),CHAR(69,111,19,5...
# 25                         '%28--%9E%5C/style%2E%3C/scRipt%9E%9CscRipt%7Enetsparker(8x54354F)%5C/scRipt%1E
# 30            /handler_sync_example.example?i=IGnn4yUfWDWRW/s5k7fOmWINPyP8/oNUNNFGK5I2sA6OhKUDrBWSc7RhuHo=
# 34            getElementsByTagName(e)[6]%76%4E%3Clink%11rel=prefetch%47href=84383%5E;s.example.example(t,s
# 36     Category=%example.example%97;%19SID=%66697F4ED8E2CD9EEF6AC6B9E8DA22183B%46;%53PSID=%35499A1C3A37...
# 39     /registration/zh-sg/?utm_campaign=cta_&game=wows&utm_medium=4796&utm_source=wotcpu&lpsn=WoWS+WGN...
# 45          ' union\tselect smfnrr (\t991, 64, (dmjvyo()),  vrmfxo#\r(), wragcd(), 'mslhod', (#\r678), 99)
# 46            /handler_sync_example.example?i=VQvhcUQNO7XuQhQ62IeRQqjZ5/tqxSG/oH5a+mqvhstbDM+OnGojZBVBmSY=
# 50     %D5%2C.%D7%52%D8%B7%D2%B9%D2%B3%D9%BE%55whitebox%6D%1A%3B%3B%8B%3D%3ACisco%52anyconnect:%2D%5A*%...
# 51     /identity/example.example?ts=933937125&url=https://example.example/novosti-i-analitika/khod-torg...
# 52           getElementsByTagName(e)[1];s.example.example(t,s=%12%8E%2Clink%17rel=prefetch%78href=33155%8E
# 59     https://example.example.com/special/admin/clients/example.example?my_query=SELECT+TOP+2277+c.Use...
# 63     /auth/login?email=&inn=%11%3E%7Cimg%46src=9%77onerror=javascript:alert(562)%2E&password=&phone=&...
# 64            /handler_sync_example.example?i=yzNCCLCgio1CL82qhqLM8Tc2Z9yJVjOkej5uS8cEVT7UCO171b/f+oNdlRs=
# 67     /admarvel/?referrer=http://149.829.398.495/topik/ngentot-mama-lagi-tidur-lelap/&continue=wpob://...
# 68            /handler_sync_example.example?i=E/gKKLlL2y34fgQ//QxWAII8IkWTloNAbgGxT/GH7UGa/ondDniPFQaK6UY=
# 71     /ar/job-search-results/?careerlevel=4&jb_loc_list=es,9,4&jb_role=9&keyword=..%61813F..%45381F..%...
# 74            /handler_sync_example.example?i=68etMNpQLLJhFNjeL7xstZI1s7VZLK3GAIOakNJ/nucFupTjbazHU+ONflA=
# ...                                                                                                    ...
# 65781  /web/example.example/restore?password=772%37%13src=%97http://example.example.com/example.example...
# 65785  %3B%78customFieldMapping%88:[%3B%45genId%19:8,%87id%71:%714437198%58%3D],%17workflowMapping%59:[...
# 65787                        �
# R�hrЕ��_�<Q�N�r����V�(#˖��ܔP�R1��A;\n�(�...<some bytes>...H��� ��
# 65789  https://example.example.example.example/collections/edan/example.example?searchTerm=najlepszy+%9...
# 65791  4 union distinct\t--762 763 afckkm \rselect--196 fdhepm 288 tpgxkp criedu \r--yyfgfu 79 388 917 ...
# 65792         /handler_sync_example.example?i=oLvZffOB3oBVHwsgO3COl8o9MzHE7/OnopZl6KL8CxHesDQT84EROmrfzO7=
# 65798  %5B469763166:%29%3B%87x%67:8,%82y%33:7,%56width%44:3,%83height%82:2%4D,%67649661121:%16%1B%47x%3...
# 65799  %8C?xml%78version=%551.9%11?%3E%9Cchart%6E%1Cmessage%7E%4Ca%58href=%78javascript:alert(8)%84%5Ec...
# 65803  226  union all/*!61 \t\tselect ( vnfwqy(*/(lftduf ()))), oypthl ((jxwlbi ())), iqbxds(\tbqcdep()...
# 65804
# ��<9�JQJ
# J5��y�O|N�
# �
# R��C65h}[k'��X��`��d*�A��3�
# {װ��I+v�uWh����������\r�M"���Z�Z...
# 65806         /handler_sync_example.example?i=jsuMelVtS5PboHa7+OnKsJqaaBfeBgYe54GKlLKwZA8xuf3pj3gx9QzCOyU=
# 65807  "  uniondistinct\t/*!1 \tselect\t*/pqlrgf(), (\tpdpbgx(\t(758))), (ghuxpa ()), wsspxk(), (bratge...
# 65809         /handler_sync_example.example?i=j/e/InuvBYvKItQ2lTzAkF+onkajCk7nWyO22JatnoalbMfLMDhbiztV8rA=
# 65811  ��}���d��G�\
# ���s�lR��(By2�!�����N}�)�$���...<some bytes>...�r��iEj�#��
# �Ԍ�O�SRCď\t1 ...
# 65813         /handler_sync_example.example?i=nwUH/TEAYX6FjUH/f5FIsjHhqrJ1ScHTZlpIliB6KeXL/ontdFa5Cv62oDs=
# 65814  835 union/**/select--785 455 653 \r(mgixdd()), ghklmh#\r((hedvml())), wxldft(#jpkapd ugdjua 516 ...
# 65816  Category=%example.example%73;%31SID=%19BE53327E9952355C24BA345ABFBF5531%52;%57PSID=%888BFC9D8A61...
# 65817            /cgi-bin/example.example?%2Cmeta%25http-equiv=Set-Cookie%74content=%23testcqjy=6528%74%5E
# 65826         /handler_sync_example.example?i=xA27jrbUywGLoO2lPOEWcJ6o1UViINpksewCxw2ezQgHwx3WrrK+ONiqiZ2=
# 65830                     "  union /*!select( pokxla(*/(jltoft ()), (vartgi()), (212), (chjltf()), (946)))
# 65831         /handler_sync_example.example?i=MmxEFa915Xkh2ZFnH29SpomH7j4/A+ONOazhPwZLrjHL1gTD2cwVn7trHyI=
# 65832  /catalog/tovari/akkumuliator-avtomobilnyi-moll-mg-standard-asia-1st-842-priam-notice-use-of-unde...
# 65833         /handler_sync_example.example?i=7kCYG4rhJWFtfvjtV7wPVjRhTHITpOa+ZpSDg8awkYW7SdzRh+oNgyMD5H1=
# 65836  {"taskId":898496643,"userUid":"bot-142454935-Conference","description":"<span style=\"background...
# 65838  /web/registration?passwordConfirmation=364%69src=http://example.example.com/example.example&pass...
# 65842  /admarvel/?referrer=http://example.exampleexample.example/&continue=wpob://hide/1z2tikbszkyxfd3f...
# 65847  /example.example?Session=NWG6BNXVW8OXL&View=List&ReturnJavaScript=9&FolderID=5&ContentType=javas...
# 65849  /ar/oman/jobs/business-development-manager-..%24992F..%52574F..%71771F..%55512F..%19885F..%82615...
# 65850         /handler_sync_example.example?i=R6h7gDYJou38m8eaONQVKmMQ+27jHYhSUNE+5O1awIElnpoc/ONnhuAqaYk=
# 65852         /handler_sync_example.example?i=PHqomsUPFgwT+ongeF+E1lNYH6ZTMJHFx6UwoZy9pShuVK3c4aoREuAaRO8=
#
#        injection  class
# 0           True      0
# 1           True      0
# 2           True      0
# 6           True      0
# 7           True      0
# 9          False      0
# 12          True      0
# 13          True      0
# 15         False      0
# 16          True      0
# 21          True      0
# 23          True      0
# 24          True      0
# 25          True      0
# 30         False      0
# 34          True      0
# 36          True      0
# 39          True      0
# 45          True      0
# 46         False      0
# 50          True      0
# 51         False      0
# 52          True      0
# 59         False      0
# 63          True      0
# 64         False      0
# 67         False      0
# 68         False      0
# 71          True      0
# 74         False      0
# ...          ...    ...
# 65781       True      0
# 65785       True      0
# 65787      False      0
# 65789      False      0
# 65791       True      0
# 65792      False      0
# 65798       True      0
# 65799       True      0
# 65803       True      0
# 65804      False      0
# 65806      False      0
# 65807       True      0
# 65809      False      0
# 65811      False      0
# 65813      False      0
# 65814       True      0
# 65816       True      0
# 65817       True      0
# 65826      False      0
# 65830       True      0
# 65831      False      0
# 65832      False      0
# 65833      False      0
# 65836      False      0
# 65838       True      0
# 65842      False      0
# 65847       True      0
# 65849       True      0
# 65850      False      0
# 65852      False      0
#
# [27703 rows x 4 columns]

# %%
cluster_sizes = [len(result[result['class'] == x]) for x in range(-1, n_clusters-1)]
injection_part_sizes = [len(result[(result['class'] == x) & (result['injection'] == True)]) for x in range(-1, n_clusters-1)]
percentage = [injection_part_size / cluster_size for cluster_size, injection_part_size in zip(cluster_sizes, injection_part_sizes)]
homogeneity = [x if x > 0.5 else 1 - x for x in percentage]

homogeneity = {i: round(x, 3) for i, x in enumerate(homogeneity)}
mean = np.mean(list(homogeneity.values()))
homogeneity
# Out:
# {0: 0.574,
#  1: 0.507,
#  2: 1.0,
#  3: 0.518,
#  4: 1.0,
#  5: 1.0,
#  6: 1.0,
#  7: 0.5,
#  8: 1.0,
#  9: 0.857,
#  10: 1.0,
#  11: 1.0,
#  12: 1.0,
#  13: 0.971,
#  14: 1.0,
#  15: 1.0,
#  16: 1.0,
#  17: 0.887,
#  18: 1.0,
#  19: 1.0,
#  20: 1.0,
#  21: 1.0,
#  22: 1.0,
#  23: 1.0,
#  24: 1.0,
#  25: 1.0,
#  26: 1.0,
#  27: 1.0,
#  28: 1.0,
#  29: 0.688,
#  30: 1.0,
#  31: 0.987,
#  32: 1.0,
#  33: 1.0,
#  34: 1.0,
#  35: 1.0,
#  36: 1.0,
#  37: 0.785,
#  38: 1.0,
#  39: 1.0,
#  40: 1.0,
#  41: 1.0,
#  42: 1.0,
#  43: 1.0,
#  44: 1.0,
#  45: 1.0,
#  46: 1.0,
#  47: 1.0,
#  48: 1.0,
#  49: 1.0,
#  50: 1.0,
#  51: 1.0,
#  52: 0.971,
#  53: 1.0,
#  54: 1.0,
#  55: 1.0,
#  56: 1.0,
#  57: 1.0,
#  58: 1.0,
#  59: 1.0,
#  60: 1.0,
#  61: 1.0,
#  62: 1.0,
#  63: 0.833,
#  64: 1.0,
#  65: 1.0,
#  66: 1.0,
#  67: 0.964,
#  68: 1.0,
#  69: 0.962,
#  70: 1.0,
#  71: 1.0,
#  72: 1.0,
#  73: 1.0,
#  74: 1.0,
#  75: 1.0,
#  76: 1.0,
#  77: 1.0,
#  78: 0.909,
#  79: 1.0,
#  80: 1.0,
#  81: 1.0,
#  82: 1.0,
#  83: 1.0,
#  84: 1.0,
#  85: 1.0,
#  86: 1.0,
#  87: 1.0,
#  88: 1.0,
#  89: 1.0,
#  90: 1.0,
#  91: 1.0,
#  92: 1.0,
#  93: 1.0,
#  94: 1.0,
#  95: 1.0,
#  96: 1.0,
#  97: 1.0,
#  98: 1.0,
#  99: 1.0,
#  100: 1.0,
#  101: 1.0,
#  102: 1.0,
#  103: 1.0,
#  104: 1.0,
#  105: 1.0,
#  106: 1.0,
#  107: 1.0,
#  108: 1.0,
#  109: 1.0,
#  110: 1.0,
#  111: 0.833,
#  112: 1.0,
#  113: 1.0,
#  114: 1.0,
#  115: 1.0,
#  116: 1.0,
#  117: 1.0,
#  118: 1.0,
#  119: 1.0,
#  120: 1.0,
#  121: 1.0,
#  122: 1.0,
#  123: 1.0,
#  124: 1.0,
#  125: 1.0,
#  126: 1.0,
#  127: 1.0,
#  128: 1.0,
#  129: 1.0,
#  130: 1.0,
#  131: 1.0,
#  132: 1.0,
#  133: 1.0,
#  134: 1.0,
#  135: 1.0,
#  136: 1.0,
#  137: 1.0,
#  138: 1.0,
#  139: 1.0,
#  140: 1.0,
#  141: 1.0,
#  142: 1.0,
#  143: 1.0,
#  144: 1.0,
#  145: 1.0,
#  146: 1.0,
#  147: 1.0,
#  148: 1.0,
#  149: 1.0,
#  150: 1.0,
#  151: 1.0,
#  152: 1.0,
#  153: 1.0,
#  154: 1.0,
#  155: 1.0,
#  156: 1.0,
#  157: 1.0,
#  158: 1.0,
#  159: 1.0,
#  160: 1.0,
#  161: 0.8,
#  162: 1.0,
#  163: 1.0,
#  164: 1.0,
#  165: 1.0,
#  166: 1.0,
#  167: 1.0,
#  168: 1.0,
#  169: 1.0,
#  170: 1.0,
#  171: 1.0,
#  172: 1.0,
#  173: 0.95,
#  174: 1.0,
#  175: 1.0,
#  176: 1.0,
#  177: 1.0,
#  178: 1.0,
#  179: 1.0,
#  180: 0.889,
#  181: 1.0,
#  182: 1.0,
#  183: 1.0,
#  184: 1.0,
#  185: 1.0,
#  186: 1.0,
#  187: 0.667,
#  188: 1.0,
#  189: 1.0,
#  190: 1.0,
#  191: 1.0,
#  192: 1.0,
#  193: 1.0,
#  194: 1.0,
#  195: 1.0,
#  196: 1.0,
#  197: 0.8,
#  198: 1.0,
#  199: 1.0}

# %%
np.set_printoptions(threshold=10000)

# %%
np.round(vector_features[:8], 3)
# Out:
# array([[-0.   , -0.057, -0.081,  0.501,  0.422, -0.014, -0.394,  0.   ,
#         -0.629,  0.049,  0.073,  0.316,  0.676,  0.517, -0.966, -0.573,
#          0.249, -0.596,  0.189, -0.541,  0.384, -0.321, -1.   ,  0.424,
#          0.275,  0.   ,  0.261, -0.08 , -0.   ,  0.007,  0.012, -0.088,
#          0.229,  0.   ,  0.104, -0.026, -0.128,  0.   ,  0.315,  0.587,
#          0.37 ,  0.891, -0.394, -0.216, -0.177, -0.033, -0.661,  0.97 ,
#         -0.496, -0.331, -0.386, -0.392,  0.311, -0.389,  0.722, -0.611,
#          0.   , -0.518,  0.281, -0.387, -0.292, -0.042, -0.608, -0.367],
#        [-0.   ,  0.057,  0.106,  0.555,  0.325, -0.006, -0.334,  0.   ,
#         -0.666,  0.011,  0.034,  0.343,  0.629,  0.524, -1.   , -0.604,
#          0.464, -0.699,  0.107, -0.5  ,  0.458, -0.28 , -1.   ,  0.653,
#          0.225,  0.059,  0.39 , -0.165, -0.   , -0.146,  0.174,  0.093,
#          0.223,  0.01 ,  0.043, -0.163, -0.104,  0.   ,  0.309,  0.517,
#          0.494,  0.827, -0.285, -0.484,  0.063, -0.071, -0.601,  0.971,
#         -0.34 , -0.347, -0.462, -0.355,  0.199, -0.516,  0.737, -0.619,
#          0.   , -0.621,  0.508, -0.627, -0.132,  0.208, -0.764, -0.34 ],
#        [-0.067,  0.012, -0.158,  0.453,  0.383, -0.   , -0.326,  0.   ,
#         -0.725,  0.   , -0.12 ,  0.373,  0.69 ,  0.567, -0.999, -0.533,
#          0.135, -0.671,  0.175, -0.518,  0.47 , -0.214, -0.967,  0.602,
#          0.206, -0.   ,  0.333, -0.217, -0.   , -0.185,  0.187, -0.116,
#          0.339,  0.   ,  0.016, -0.17 , -0.074,  0.   ,  0.34 ,  0.534,
#          0.482,  0.849, -0.29 , -0.033,  0.079, -0.038, -0.719,  0.892,
#         -0.175, -0.345, -0.412, -0.381,  0.203, -0.512,  0.704, -0.511,
#          0.031, -0.643, -0.013, -0.585, -0.057,  0.135, -0.666, -0.385],
#        [-0.444,  0.459, -0.57 ,  0.595,  0.216, -0.168, -0.236,  0.017,
#         -0.81 ,  0.276, -0.437,  0.498, -0.461,  0.5  , -1.   ,  0.035,
#          0.331, -0.547,  0.462,  0.   ,  0.366, -0.199, -0.385,  0.536,
#         -0.392,  0.04 ,  0.584, -0.144,  0.332, -0.105,  0.   ,  0.527,
#          0.272,  0.107,  0.1  , -0.093, -0.248,  0.075,  0.   , -0.506,
#          0.989,  0.453, -0.285,  0.13 ,  0.   ,  0.009, -0.457,  0.464,
#         -0.568,  0.159, -0.541, -0.289,  0.044,  0.3  ,  0.573,  0.031,
#          0.   , -0.677, -0.045, -0.701, -0.295, -0.542, -0.402, -0.004],
#        [-0.264, -0.038,  0.096,  0.468,  0.557, -0.119, -0.179,  0.   ,
#         -0.615,  0.   , -0.585,  0.257,  0.696,  0.495, -0.994, -0.461,
#         -0.014, -0.52 ,  0.142, -0.47 ,  0.331, -0.114, -1.   ,  0.737,
#          0.341, -0.136,  0.146, -0.059, -0.091, -0.091,  0.032, -0.379,
#          0.277,  0.   ,  0.099, -0.234, -0.042,  0.   ,  0.363,  0.554,
#          0.452,  0.925, -0.37 ,  0.517, -0.012, -0.056, -0.721,  0.751,
#         -0.824, -0.482, -0.34 , -0.341,  0.112, -0.411,  0.747, -0.394,
#          0.012, -0.589,  0.142, -0.598, -0.328,  0.217, -0.456, -0.385],
#        [-0.404,  0.128,  0.189,  0.689,  0.238, -0.202, -0.2  ,  0.033,
#         -0.797,  0.237,  0.323,  0.504, -0.483,  0.493, -0.93 ,  0.033,
#          0.293, -0.717,  0.305,  0.   ,  0.22 , -0.28 , -0.431,  0.719,
#         -0.406,  0.062,  0.301, -0.108,  0.308,  0.   ,  0.165,  0.215,
#          0.167,  0.164,  0.048, -0.069, -0.135,  0.06 ,  0.015, -0.441,
#          0.98 ,  0.47 , -0.285,  0.104,  0.111, -0.003, -0.442,  0.468,
#         -0.65 ,  0.191, -0.619, -0.337,  0.048,  0.177,  0.597, -0.292,
#          0.   , -0.689, -0.033, -0.936, -0.266, -0.686, -0.474, -0.025],
#        [-0.   ,  0.04 ,  0.26 ,  0.472,  0.186, -0.   , -0.245,  0.   ,
#         -0.711,  0.15 ,  0.309,  0.345,  0.658,  0.511, -1.   , -0.473,
#          0.753, -0.73 ,  0.031, -0.449,  0.453, -0.326, -0.94 ,  0.558,
#          0.132,  0.019,  0.299, -0.097, -0.   , -0.21 ,  0.623,  0.308,
#          0.299,  0.041,  0.134, -0.025, -0.156,  0.   ,  0.23 ,  0.598,
#          0.536,  0.741, -0.283, -0.437,  0.344, -0.026, -0.606,  0.995,
#         -0.182, -0.266, -0.432, -0.543,  0.118, -0.578,  0.749, -0.527,
#          0.   , -0.607,  0.627, -0.594, -0.224, -0.566, -0.714, -0.312],
#        [ 0.003,  0.008, -0.289,  0.505,  0.428, -0.085, -0.234,  0.   ,
#         -0.723,  0.   , -0.631,  0.364,  0.634,  0.567, -0.969, -0.564,
#          0.188, -0.677, -0.219, -0.401,  0.187, -0.148, -1.   ,  0.489,
#          0.186, -0.152,  0.169, -0.116, -0.   , -0.003,  0.035,  0.454,
#          0.286,  0.   ,  0.064,  0.226, -0.057,  0.   ,  0.357,  0.496,
#          0.298,  0.861, -0.208,  0.013, -0.082, -0.195, -0.655,  0.645,
#         -0.491, -0.388, -0.471, -0.289,  0.292, -0.528,  0.709, -0.667,
#          0.006, -0.629,  0.437, -0.596, -0.199,  0.16 , -0.676, -0.38 ]],
#       dtype=float32)
