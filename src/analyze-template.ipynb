# %%
import pandas as pd
import numpy as np
import requests
import os

from keras.engine.topology import Layer, InputSpec
from keras.layers import Dense, Input, Embedding
from keras.layers.recurrent import LSTM
from keras.models import Model
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.sequence import pad_sequences
import keras.backend as K

from utils.vocab import Vocabulary
from sklearn.cluster import KMeans
from joblib import load

from utils.plot_utils import plot_and_save_history
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Utils

# %%
class AutoEncoder(object):
    """ 4-layer LSTM Autoencoder
    Parameters
        vocab: Vocabulary object that stores char-to-int mappings 
            and text processing functions.
        hidden_size: Dimension of latent space between encoder and decoder.
            Default: 64.
        dropout: Fraction of units to be randomly ignored during training.
            Both linear and recurrent dropout are used.
            Default: 0.2.
    """
    DEFAULT_HIDDEN_UNITS = 64
    DEFAULT_DROPOUT = 0.2
    DEFAULT_BATCH_SIZE = 64
    DEFAULT_EPOCHS = 100
    DEFAULT_MODEL_WEIGHT_PATH = './models/autoencoder-weights.h5'
    model_name = 'autoencoder'

    def __init__(self, vocab, hidden_size=None, dropout=None):
        if not hidden_size:
            self.hidden_size = AutoEncoder.DEFAULT_HIDDEN_UNITS
        if not dropout:
            self.dropout = AutoEncoder.DEFAULT_DROPOUT
            
        self.vocab = vocab
        self.vocab_size = vocab.vocab_size
        self.max_input_seq_length = vocab.max_input_seq_length

        encoder_inputs = Input(shape=(None,), name='encoder_inputs')
        encoder_embedding = Embedding(input_dim=self.vocab_size,
                                      output_dim=self.hidden_size,
                                      input_length=self.max_input_seq_length,
                                      name='encoder_embedding')
        encoder_lstm = LSTM(units=self.hidden_size,
                            return_state=True,
                            dropout=self.dropout,
                            recurrent_dropout=self.dropout,
                            name='encoder_lstm')
        encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_embedding(encoder_inputs))
        encoder_states = [encoder_state_h, encoder_state_c]

        decoder_inputs = Input(shape=(None, self.vocab_size), name='decoder_inputs')
        decoder_lstm = LSTM(units=self.hidden_size, return_state=True,
                            return_sequences=True, name='decoder_lstm')
        decoder_outputs, decoder_state_h, decoder_state_c = decoder_lstm(decoder_inputs,
                                                                         initial_state=encoder_states)
        decoder_dense = Dense(units=self.vocab_size, activation='softmax', name='decoder_dense')
        decoder_outputs = decoder_dense(decoder_outputs)

        model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

        model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

        self.model = model

        self.encoder_model = Model(encoder_inputs, encoder_states)

        decoder_state_inputs = [Input(shape=(self.hidden_size,)), Input(shape=(self.hidden_size,))]
        decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs,
                                                         initial_state=decoder_state_inputs)
        decoder_states = [state_h, state_c]
        decoder_outputs = decoder_dense(decoder_outputs)
        self.decoder_model = Model([decoder_inputs] + decoder_state_inputs,
                                   [decoder_outputs] + decoder_states)

    def load_weights(self, weight_file_path):
        if os.path.exists(weight_file_path):
            self.model.load_weights(weight_file_path)

    def generate_batch(self, samples, batch_size):
        num_batches = len(samples) // batch_size
        while True:
            for batchIdx in range(0, num_batches):
                start = batchIdx * batch_size
                end = (batchIdx + 1) * batch_size
                encoder_input_data_batch = pad_sequences(samples[start:end], self.max_input_seq_length)
                decoder_target_data_batch = np.zeros(shape=(batch_size, self.max_input_seq_length,
                                                            self.vocab_size))
                decoder_input_data_batch = np.zeros(shape=(batch_size, self.max_input_seq_length,
                                                           self.vocab_size))
                for textIdx, chars in enumerate(samples[start:end]):
                    for idx, char in enumerate(chars):
                        if char != 1: # not <UNK>
                            decoder_input_data_batch[textIdx, idx, char] = 1
                            if idx > 0:
                                decoder_target_data_batch[textIdx, idx - 1, char] = 1
                yield [encoder_input_data_batch, decoder_input_data_batch], decoder_target_data_batch

    def fit(self, Xtrain, Xtest, epochs=None, batch_size=None, weight_file_path=None):
        """
        Train model.
        Parameters:
            Xtrain: Array of strings for training.
            Xtest: Array of strings for validation.
            epochs: Number of full forward passes of all training samples.
                Default: 50.
            batch_size: Number of samples to pass for one iteration.
                Default: 64.
            weight_file_path: File path with extension '.h5'
                for saving weights of the network. (https://www.h5py.org/)
                Default: ./models/autoencoder-weights.h5
        """

        if not epochs:
            epochs = AutoEncoder.DEFAULT_EPOCHS
        if not batch_size:
            batch_size = AutoEncoder.DEFAULT_BATCH_SIZE
        if not weight_file_path:
            weight_file_path = AutoEncoder.DEFAULT_WEIGHT_FILE_PATH

        checkpoint = ModelCheckpoint(weight_file_path)

        Xtrain = self.vocab.transform_texts(Xtrain)
        Xtest = self.vocab.transform_texts(Xtest)

        train_gen = self.generate_batch(Xtrain, batch_size)
        test_gen = self.generate_batch(Xtest, batch_size)

        train_num_batches = len(Xtrain) // batch_size
        test_num_batches = len(Xtest) // batch_size

        history = self.model.fit_generator(generator=train_gen, steps_per_epoch=train_num_batches,
                                           epochs=epochs, verbose=True,
                                           validation_data=test_gen, validation_steps=test_num_batches,
                                           callbacks=[checkpoint])
        self.model.save_weights(weight_file_path)
        return history

    def predict(self, input_text):
        """
        Process input texts and reconstruct them.
        Used to check how well model "understands" input texts.
        Parameters:
             input_text: 
        """
        input_seq = self.vocab.transform_texts([input_text])
        states_value = self.encoder_model.predict(input_seq)
        target_seq = np.zeros((1, 1, self.vocab_size))
        target_seq[0, 0, self.vocab.char2idx['<START>']] = 1
        target_text = ''
        target_text_len = 0
        terminated = False
        while not terminated:
            output_tokens, h, c = self.decoder_model.predict([target_seq] + states_value)

            sample_token_idx = np.argmax(output_tokens[0, -1, :])
            sample_char = self.vocab.idx2char[sample_token_idx]
            target_text_len += 1

            if sample_char != '<START>' and sample_char != '<END>':
                target_text += ' ' + sample_char

            if sample_char == '<END>' or target_text_len >= self.max_input_seq_length:
                terminated = True

            target_seq = np.zeros((1, 1, self.vocab_size))
            target_seq[0, 0, sample_token_idx] = 1

            states_value = [h, c]
        return target_text.strip()

# %%
def get_features(vectors):
    # vector: string -> vector_embedding: [char_indices]
    # [char_indices] are padded with 0 to the right
    vector_embedding = vocab.transform_texts([vector])
    
    # vector_embedding: [char_indices] -> encoders_states: [state_h, state_c]
    encoder_states = encoder.predict([vector_embedding])
    
    # use state_h as feature
    vector_features = encoder_states[0]
    
    return vector_features

# %%
def predict_class(vector_features):
    vector_class = kmeans.predict(vector_features)[0]
    # "0"-class is invalid
    if vector_class == 0:
        vector_class = 25
    return vector_class

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Load data

# %%
pd.set_option('display.max_colwidth', 100)

# %%
data = pd.read_csv('../data/wallarm.csv', encoding='utf-8', lineterminator='\n')
data = data.fillna('<BLANK>')

# %% [markdown]
# ### Load autoencoder

# %%
from keras import backend as K

K.set_learning_phase(0) #set testing phase

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = ''

# %%
vocab = Vocabulary()
vocab.vocab_file = './vocab-wallarm.json'
vocab.make_vocab(data['text'])
autoencoder = AutoEncoder(vocab)
autoencoder.load_weights('./models/train-wallarm.h5')
encoder = autoencoder.encoder_model

# %% [markdown]
# ### Train K-Means

# %%
vector_embeddings = vocab.transform_texts(data['text'])
encoder_states = encoder.predict(vector_embeddings)
vector_features = encoder_states[0]

# %% [markdown]
# ### Predict for 2 classes

# %%
kmeans = KMeans(n_clusters=8, n_init=10, n_jobs=-1)
labels = kmeans.fit_predict(vector_features)
result = pd.DataFrame(data)
result['class'] = labels

# %%
result[result['class'] == 0]
# Out:
#           id  \
# 9      42354
# 15     16094
# 30     13209
# 46      7454
# 64     35367
# 68      6038
# 74     10575
# 97      7168
# 108     1956
# 109     1361
# 116    15780
# 128    42174
# 135    30838
# 149    33744
# 159    28569
# 180    34468
# 182    10281
# 204     3043
# 211    37386
# 226    36331
# 237    20818
# 241     4935
# 249    36269
# 253    99641
# 265    23912
# 275    43973
# 278    21635
# 286    30664
# 295    14146
# 296    28241
# ...      ...
# 65608   7462
# 65612    933
# 65620  22120
# 65624  37263
# 65625  34983
# 65638   9641
# 65650  20779
# 65661  40154
# 65662  22454
# 65665  44715
# 65674  15973
# 65689  24018
# 65707  17393
# 65708  43938
# 65715   6608
# 65724  32436
# 65741    184
# 65751   2484
# 65760  18424
# 65766  32241
# 65775  44367
# 65792  42736
# 65806  20126
# 65809  20792
# 65813  44224
# 65826  28332
# 65831  19108
# 65833  11731
# 65850   1268
# 65852  26176
#
#                                                                                                       text  \
# 9             /handler_sync_example.example?i=j4sR/mhZpekzcpKcC5cUoFHo5e42TQeA6YzVZuR3mhhuaivOgsA/oncCkpo=
# 15            /handler_sync_example.example?i=Ypg//ONuVSKGXMnxmNJk8d6NQDTWwBs9OUBxw7FuiARcp4PPJBes4cIR26Q=
# 30            /handler_sync_example.example?i=IGnn4yUfWDWRW/s5k7fOmWINPyP8/oNUNNFGK5I2sA6OhKUDrBWSc7RhuHo=
# 46            /handler_sync_example.example?i=VQvhcUQNO7XuQhQ62IeRQqjZ5/tqxSG/oH5a+mqvhstbDM+OnGojZBVBmSY=
# 64            /handler_sync_example.example?i=yzNCCLCgio1CL82qhqLM8Tc2Z9yJVjOkej5uS8cEVT7UCO171b/f+oNdlRs=
# 68            /handler_sync_example.example?i=E/gKKLlL2y34fgQ//QxWAII8IkWTloNAbgGxT/GH7UGa/ondDniPFQaK6UY=
# 74            /handler_sync_example.example?i=68etMNpQLLJhFNjeL7xstZI1s7VZLK3GAIOakNJ/nucFupTjbazHU+ONflA=
# 97            /handler_sync_example.example?i=d7Mau9dhQF8TG1R/OnfnvrKUSDcenjrAggRbD9WGWvry98QyzC4WZAusiEk=
# 108           /handler_sync_example.example?i=eoB/y25gymKn+J/ZE7inLL/RGceV29iE6sw9tiDSJ44yGnVE6/OnpnYieV1=
# 109           /handler_sync_example.example?i=YZrBVzimSaztRDWOLkRiaqu+T/oNuJgGJhLk5yvpg6dWfwjU1ugDXCoVQCk=
# 116           /handler_sync_example.example?i=4jk9ds7+AEqvwI7ZDecyesxRW7aGgyy1+51qB6D/onnvpEcz4gdFMDfsU41=
# 128           /handler_sync_example.example?i=wDT4QikolcL7ZLTjV9hPuDhWhUXeUUhDp1sYzWw/RxHR+6WHVQNJc+OnkIM=
# 135           /handler_sync_example.example?i=IoLW9HhseLq3JyRPMI7yNf3cSb7lM+X3ghF1cg+ONcjooKvaEoGLeULAVb2=
# 149           /handler_sync_example.example?i=XxkxebRGddFxoCJqPtveXV+APCBUG/onBfQEKoC7W12XzYQaHao9VUjqlic=
# 159           /handler_sync_example.example?i=P/onVBOzWH52deltpZxumsqJ5XWkcVYuX91tQ7yB7FFvYF2BdTH85DgWNGc=
# 180           /handler_sync_example.example?i=zvfvtoOg6cQ9kak7WSpqW3TjsuDJajKuB+OnOVfNTwenb5qFYIimJkr3L5A=
# 182           /handler_sync_example.example?i=rmq31d+ONhfTGbJzizshRwUGR3uznFruAr6BCi65B1xgf9U4ZikUCBoJU2o=
# 204           /handler_sync_example.example?i=1Gg7hXiylkcf+oN1xayhTXkLNOvqXR9caxsYpfrMf9w/onmYIgg9foWFuF4=
# 211               /handler_sync_example.example?i=YTECIhdXRyEG5/3lUBOWlFupzA7RhpJFrQUjD+UyC1F7HaX+onbYCw==
# 226           /handler_sync_example.example?i=d8Bru1cVt/gj8BeGxUyhCk6E5Hal92z3TJ/OnlzsVGWZJxlbWANl3CggeXs=
# 237           /handler_sync_example.example?i=ry1TU8ys8cL3wNDCAHgEmS8R7IWq4W3sayn8U5B73lHJr+oNNQdZT7cZ9Bk=
# 241           /handler_sync_example.example?i=Ylys9Ri1pyRZrUUYOTFq2reBt+ONNcTJ3lItQf47UQcaltSfvfW7TjXdgX8=
# 249           /handler_sync_example.example?i=RGYOqO1rm1paWOI6ezDPBS8CJXlq/qljn5MO95a+onoNtsYJpIvvkmWmNf6=
# 253    /example.example?Session=ZHAADI6G822ZU&View=List&ReturnJavaScript=9&FolderID=3&Sort=RevDate&Page...
# 265           /handler_sync_example.example?i=8lueYYHrbD7I/OnDQXBbOTybzo7YwuTHEpdaJFa4BWzJYNbHuAVtZKOQgrU=
# 275           /handler_sync_example.example?i=MmvToBDvIzpmFA9Tgiy6oAjTJP2wF2FepqVBADQGn/5JY/oNRKNxxqmA4vY=
# 278           /handler_sync_example.example?i=kvvcrYjf2ncKmNudV8RlaRw9MnjY12tnwJqFt7awWwOy3/OnAWDScbWTork=
# 286           /handler_sync_example.example?i=3gOaJ3KKuJd9MOfOIV+YdFk9/onpteezxnRbYDjtOKLuxZLN1SCB64Jts9U=
# 295           /handler_sync_example.example?i=si14d1NmYM8+BxEDmkKSJ2SvGoNlVLBinV/DHkz8uHHp+onaxzRY7g8YTqg=
# 296           /handler_sync_example.example?i=1ZM9B6zG3iFmlgBnGfBfNV6paoEMJRRSwa7MOJBroGT3eR6Iywm8+ONHOok=
# ...                                                                                                    ...
# 65608         /handler_sync_example.example?i=aQJX+4XDIRb2s9fboWHVdCk2y/5fMtugjM9hXoDa2f1VVgSBo3+ONuqifok=
# 65612         /handler_sync_example.example?i=MQxNeEFl8IsdrkWpt6ZXAf/OnRmwYoIYnhRd4dlrlExEKfpnmBIGwZRMnYo=
# 65620         /handler_sync_example.example?i=8QtHZOcZgJjZpXs6+sg+qS9/onLNa/zTllzlhD6bPjdgqVDJljiJRv3DCH9=
# 65624         /handler_sync_example.example?i=dRyRwotllFEW+ONtVBelL6BkG7EPbw33EK2yLu2Kd2w9wcxAd8W8N5jvmHM=
# 65625         /handler_sync_example.example?i=y6t1e7oUVR/oNnFbHOGZA5wqWYwWSjTA4d5xm3KBMc62cK3eROj1fjURYbw=
# 65638         /handler_sync_example.example?i=dJkjR2a84yD2EB24L5olUa78LN/PG5Ot7wbWN2QNsSR+oNWFegw5x2QzchY=
# 65650         /handler_sync_example.example?i=5JKtBXypXPr1+ONPTzzoT7DQUBiE1uKQyZE5lde78d1H9Qlbl5xo6hfcazA=
# 65661         /handler_sync_example.example?i=VolrZAwZgbxCL+lrjEMPUTWXylFXSX2zTUIj6rXuuft+qzPZ+pr3Q+ONmaY=
# 65662         /handler_sync_example.example?i=1gTNzw9C9daQbOcImwl6NlCpLI4zI/6BRb4/ywtCBFwpGOa6F3+ONEkkPjI=
# 65665         /handler_sync_example.example?i=+OnexCxVGd1me5diqdERuPf4wLm48lfMEX3QAhTVweRUuqrtFJPBj317N9M=
# 65674         /handler_sync_example.example?i=u5Lj6NowJVeKxj4Pd6XyUtIvEK1TGx/ONOwRw9a4EGCwwwZBe31tznEsDKA=
# 65689         /handler_sync_example.example?i=gf3ssaABY2ICgST/3EE92rhI+xl/Hn1ChRmiE4EsGl7V+g+ONTLen4zlEaE=
# 65707         /handler_sync_example.example?i=D2bvKHIzoAiBvLGmOB+onCJgwMfFJFD1SlG5fmPU9dj9DkwdGuMNzektats=
# 65708         /handler_sync_example.example?i=9rytj5HB7ZbZm+RjG9QYW23gCoiVneduG2Iadh+ONgsbjmSuPo1NPYOSVEQ=
# 65715         /handler_sync_example.example?i=z84vg6F85kM96bDmq8tiCJmZwkyaQPxb6dvR2TLts5UArIopp/ONFDxR137=
# 65724         /handler_sync_example.example?i=y5Fyud5+d7XcN8E+W6oNw6LiSN9BlujtWpZlbjZaiUDwNdtreS/onpQgy7k=
# 65741         /handler_sync_example.example?i=iJHJ1eWYlmIryUPeOimj/RrZ1cEuftAvcWyuTuMai36wkTc+ONdjhb4e84E=
# 65751         /handler_sync_example.example?i=fqizZDmZoiL8bl8gBgxt/uD9Xbv5jl6X+55MZZVb3d3BH1L+onBGreiPuVs=
# 65760         /handler_sync_example.example?i=uA7q+exa8t3Y3SguTv1LtiH/uK6rPrtaUCZnO6s/U+onHGuzs7qMpAp8TLk=
# 65766         /handler_sync_example.example?i=nrY5VsQDGGw2FhoUVS95/jkrtm9iDWerpIlolbKYPWXq+OnttcLVwYhwsuY=
# 65775         /handler_sync_example.example?i=lpy6gVEW6qViKydNs3a8EhivgPlra4k48XrTVUI2e9EuhA/onFCWUXiLfyc=
# 65792         /handler_sync_example.example?i=oLvZffOB3oBVHwsgO3COl8o9MzHE7/OnopZl6KL8CxHesDQT84EROmrfzO7=
# 65806         /handler_sync_example.example?i=jsuMelVtS5PboHa7+OnKsJqaaBfeBgYe54GKlLKwZA8xuf3pj3gx9QzCOyU=
# 65809         /handler_sync_example.example?i=j/e/InuvBYvKItQ2lTzAkF+onkajCk7nWyO22JatnoalbMfLMDhbiztV8rA=
# 65813         /handler_sync_example.example?i=nwUH/TEAYX6FjUH/f5FIsjHhqrJ1ScHTZlpIliB6KeXL/ontdFa5Cv62oDs=
# 65826         /handler_sync_example.example?i=xA27jrbUywGLoO2lPOEWcJ6o1UViINpksewCxw2ezQgHwx3WrrK+ONiqiZ2=
# 65831         /handler_sync_example.example?i=MmxEFa915Xkh2ZFnH29SpomH7j4/A+ONOazhPwZLrjHL1gTD2cwVn7trHyI=
# 65833         /handler_sync_example.example?i=7kCYG4rhJWFtfvjtV7wPVjRhTHITpOa+ZpSDg8awkYW7SdzRh+oNgyMD5H1=
# 65850         /handler_sync_example.example?i=R6h7gDYJou38m8eaONQVKmMQ+27jHYhSUNE+5O1awIElnpoc/ONnhuAqaYk=
# 65852         /handler_sync_example.example?i=PHqomsUPFgwT+ongeF+E1lNYH6ZTMJHFx6UwoZy9pShuVK3c4aoREuAaRO8=
#
#        injection  class
# 9          False      0
# 15         False      0
# 30         False      0
# 46         False      0
# 64         False      0
# 68         False      0
# 74         False      0
# 97         False      0
# 108        False      0
# 109        False      0
# 116        False      0
# 128        False      0
# 135        False      0
# 149        False      0
# 159        False      0
# 180        False      0
# 182        False      0
# 204        False      0
# 211        False      0
# 226        False      0
# 237        False      0
# 241        False      0
# 249        False      0
# 253         True      0
# 265        False      0
# 275        False      0
# 278        False      0
# 286        False      0
# 295        False      0
# 296        False      0
# ...          ...    ...
# 65608      False      0
# 65612      False      0
# 65620      False      0
# 65624      False      0
# 65625      False      0
# 65638      False      0
# 65650      False      0
# 65661      False      0
# 65662      False      0
# 65665      False      0
# 65674      False      0
# 65689      False      0
# 65707      False      0
# 65708      False      0
# 65715      False      0
# 65724      False      0
# 65741      False      0
# 65751      False      0
# 65760      False      0
# 65766      False      0
# 65775      False      0
# 65792      False      0
# 65806      False      0
# 65809      False      0
# 65813      False      0
# 65826      False      0
# 65831      False      0
# 65833      False      0
# 65850      False      0
# 65852      False      0
#
# [7346 rows x 4 columns]

# %%
result[(result['class'] == 0) & (result['injection'] == True)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d9ea5b7b1b13> in <module>
# ----> 1 result[(result['class'] == 0) & (result['injection'] == True)]
#
# NameError: name 'result' is not defined
